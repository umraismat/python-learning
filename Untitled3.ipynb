# %%
def square(num):
    return (num**2)

# %%
my_nums = [1,2,3,4,5]

# %%
for item in map(square,my_nums):
    print (item)
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
list(map(square,my_nums))
# Out:
# [1, 4, 9, 16, 25]

# %%
def splicer(mystring):
    if len(mystring)%2==0:
        return 'EVEN'
    else:
        return mystring[0]

# %%
name =  ['umra','sandy','eve']

# %%
list(map(splicer,name))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 list(map(splicer,name))
#
# NameError: name 'splicer' is not defined

# %%
def check_even(num):
    return num%2 ==0

# %%
mynums = [1,2,3,4,5]

# %%
list(filter(check_even, mynums))
# Out:
# [2, 4]

# %%
for n in filter(check_even, mynums):
    print(n)
# Out:
# 2
# 4

# %%
def square(num):
    return num**2

# %%
square(9)
# Out:
# 81

# %%
 lambda num: num**2
# Out:
# <function __main__.<lambda>(num)>

# %%
square(9)
# Out:
# 81

# %%
 list(filter(lambda num: num%2==0,mynums))
# Out:
# [2, 4]

# %%
list(map(lambda name: name[0] , name))
# Out:
# ['u', 's', 'e']

# %%
x= 25


def printer():
    x=50
    return x

# %%
print(x)
# Out:
# 25

# %%
print(printer())
# Out:
# 50

# %%
#name = 'THE IS GLOBAL  STRING'

def greet():
    #name = 'umra'
    
    def hello():
       # name = 'raiyan'
        print('hello  '+name)
        
    hello()

# %%
greet()
# Out:
# hello  THE IS GLOBAL  STRING

# %%
len
# Out:
# <function len(obj, /)>

# %%
x= 50 

def func():
    global x
    print(f' X is {x}')


    x='NEW VALUE'
    print(f'I HAVE JUST  GLOBAL CHANGED X TO {x}')

# %%
print(x)
# Out:
# 50

# %%
x= func()
# Out:
#  X is None
# I HAVE JUST  GLOBAL CHANGED X TO NEW VALUE

# %%
print(x)
# Out:
# None
