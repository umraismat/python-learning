# %%
false

# %%
type(true)

# %% [markdown]
# 1>2

# %%
# %%writefile myfile.text
# hello this is my file
# this is the second file
# this is the third file
# Out:
# Writing myfile.text

# %%
myfile = open('myfile.text')

# %%
myfile = open('whoop error')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 myfile = open('whoop error')
#
# File ~/Library/Python/3.14/lib/python/site-packages/IPython/core/interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'whoop error'

# %%
pwd
# Out:
# '/Users/umra/programs'

# %%
myfile = open('myfile.text')

# %%
myfile.read()
# Out:
# 'hello this is my file\nthis is the second file\nthis is the third file\n'

# %%
myfile.read()
# Out:
# 'hello this is my file\nthis is the second file\nthis is the third file\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'hello this is my file\nthis is the second file\nthis is the third file\n'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
content = myfile.read()

# %%
content
# Out:
# 'hello this is my file\nthis is the second file\nthis is the third file\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
myfile.close()

# %%
f = open('/Users/umra/documents/test.txt')
f.readlines()
# Out:
# ['testfile']

# %%
with open('/Users/umra/documents/test.txt') as ff:
    lines = ff.readlines()

# %%
lines
# Out:
# ['testfile']

# %%
# %%writefile myfile.text
# my name is umra ismat
# my favourite fruits is banana
# my favourite work is coding
# Out:
# Overwriting myfile.text

# %%
with  open('myfile.text', mode= 'r') as ff:
    print(ff.read())
# Out:
# my name is umra ismat
# my favourite fruits is banana
# my favourite work is coding

# %%
with open('myfile.txt', mode= 'a') as ff:
    ff.write('\n four to fourth')

# %%
with open('../Documents/dirdoc/newdummy.txt', mode= 'w') as f:
    f.write('hi there!')

# %%
mylist [1,2,3,4,5,6,7,8,9]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 mylist [1,2,3,4,5,6,7,8,9]
#
# NameError: name 'mylist' is not defined
