# %%
from collections import Counter

# %%
mylist = [1,1,1,1,3,2,2,2,2,2,4,5,5,6,8,8,8,4]

# %%
Counter(mylist)
# Out:
# Counter({2: 5, 1: 4, 8: 3, 4: 2, 5: 2, 3: 1, 6: 1})

# %%
mylist = [10,10,10,'a','a']

# %%
Counter(mylist)
# Out:
# Counter({10: 3, 'a': 2})

# %%
Counter('aaaaaaaaaabbbbbbuuuuuuueeeeeeeeeiiiiiiiajjj')
# Out:
# Counter({'a': 11, 'e': 9, 'u': 7, 'i': 7, 'b': 6, 'j': 3})

# %%
sentence = 'how many time it will take to complete there word'

# %%
Counter(sentence)
# Out:
# Counter({' ': 9,
#          't': 6,
#          'e': 6,
#          'o': 4,
#          'w': 3,
#          'm': 3,
#          'i': 3,
#          'l': 3,
#          'h': 2,
#          'a': 2,
#          'r': 2,
#          'n': 1,
#          'y': 1,
#          'k': 1,
#          'c': 1,
#          'p': 1,
#          'd': 1})

# %%
Counter(sentence.split())
# Out:
# Counter({'how': 1,
#          'many': 1,
#          'time': 1,
#          'it': 1,
#          'will': 1,
#          'take': 1,
#          'to': 1,
#          'complete': 1,
#          'there': 1,
#          'word': 1})

# %%
letter = 'aaaaaaaaaaaabbbbbbbbbbddddddddddccccccccc'

# %%
c = Counter(letter)

# %%
c
# Out:
# Counter({'a': 12, 'b': 10, 'd': 10, 'c': 9})

# %%
c.most_common()
# Out:
# [('a', 12), ('b', 10), ('d', 10), ('c', 9)]

# %%
c
# Out:
# Counter({'a': 12, 'b': 10, 'd': 10, 'c': 9})

# %%
list(c)
# Out:
# ['a', 'b', 'd', 'c']

# %%
from collections import defaultdict

# %%
d = {'a':10}

# %%
d
# Out:
# {'a': 10}

# %%
d['a']
# Out:
# 10

# %%
d = defaultdict(lambda:0)

# %%
d['correct '] = 10

# %%
d['correct ']
# Out:
# 10

# %%
d['Wrong key !'] = 0

# %%
d['Wrong key !']
# Out:
# 0

# %%
d
# Out:
# defaultdict(<function __main__.<lambda>()>, {'correct ': 10, 'Wrong key !': 0})

# %%
mytuple =  (10,20,30)

# %%
mytuple[0]
# Out:
# 10

# %%
from collections import namedtuple

# %%
Dog = namedtuple('Dog',['age','breed','name'])

# %%
sammy = Dog(age=5, breed ='german', name = 'sam' )

# %%
type(sammy)
# Out:
# __main__.Dog

# %%
sammy
# Out:
# Dog(age=5, breed='german', name='sam')

# %%
sammy.name
# Out:
# 'sam'

# %%
sammy.breed
# Out:
# 'german'

# %%
sammy.age
# Out:
# 5
