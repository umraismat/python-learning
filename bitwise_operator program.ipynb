# %%
def main():
    
    
    print(5 | 9)
    print(5 & 9)
    print(5 ^ 9)



if __name__  == '__main__' :
    main()
# Out:
# 13
# 1
# 12

# %%
def main():
    print(-5>>1)
        

if __name__  == '__main__':
    main()
# Out:
# -3
