# %%
country = ''
print(f'I love {country}')
# Out:
# I love

# %%
my_list = [1,2,3]
my_list = ['stringm' ,9.0,8]
len(my_list)
# Out:
# 3

# %%
my_firstlist = [ 'sunday' , 'monday', 'tuesday', 'wednesday', 'thursday']
my_firstlist
# Out:
# ['sunday', 'monday', 'tuesday', 'wednesday', 'thursday']

# %%
my_anotherlist = ['friday', 'saturday']
my_anotherlist
# Out:
# ['friday', 'saturday']

# %%
my_firstlist + my_anotherlist
# Out:
# ['sunday', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday']

# %%
new_list =['one', 'two' , 'three' ,'four','five']
new_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
my_list[0] = 'onecap'

# %%
my_list
# Out:
# ['onecap', 9.0, 8]

# %%
my_list.append('true')
my_list
# Out:
# ['onecap', 9.0, 8, 'true']

# %%
my_list.append('love')

# %%
my_list
# Out:
# ['onecap', 9.0, 8, 'true', 'love']

# %%
1>2
# Out:
# False
