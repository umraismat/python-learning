# %% [markdown]
# running print statements

# %%
print("he there")
print(1+1)
# Out:
# he there
# 2

# %%
mylist = [1,2,3]

# %%
myset = set()

# %%
type(myset)
# Out:
# set

# %%
class Person():

    species = 'human'
    
    def __init__(self,name,age):
        self.name = name
        self.age = age
        
    def happy(self):
         print('wow! hoorah!')

    def sad(self, number):
         print('I\'M SO SAD!   my name is {} and  number {}'.format(self.name, number))

# %%
umra = Person(name='Umra',age=40)

# %%
type(umra)
# Out:
# __main__.Person

# %%
umra.species
# Out:
# 'human'

# %%
umra.happy()
# Out:
# wow! hoorah!

# %%
umra.sad(7)
# Out:
# I'M SO SAD!   my name is Umra and  number 7

# %%
class Circle():

    pi = 3.14

    def __init__ (self,radius=1):
        self.radius = radius
    def get_circumference(self):
        return self.radius * self.pi *2
    def get_area(self):
        self.area = self.radius*self.radius*self.pi
        return self.area

# %%
my_circle = Circle(30)

# %%
my_circle.radius
# Out:
# 30

# %%
my_circle.pi
# Out:
# 3.14

# %%
my_circle.get_circumference()
# Out:
# 188.4

# %%
my_circle.get_area()
# Out:
# 2826.0

# %%
class AnimalOfZoo():
    def __init__ (self):
        print('animal')
    def eat(self):
        print('i am eating')
    def whoami(self):
        print(' I AM ANIMAL')

# %%
myanimal = AnimalOfZoo()
# Out:
# animal

# %%
myanimal.eat()
# Out:
# i am eating

# %%
myanimal.whoami()
# Out:
#  I AM ANIMAL

# %%
class dog():
    
    def __init__ (self):
        AnimalOfZoo.__init__(self)
        print('dog animal')

    def bark():
        print("wooh")

# %%
dog.bark(1)
# Out:
# wooh

# %%
class Dog:
    def __init__(self, name):
        self.name = name

    def speak(self):
        return self.name+' says Woof!'
    
class Cat:
    def __init__(self, name):
        self.name = name

    def speak(self):
        return self.name+' says Meow!' 
    
niko = Dog('Niko')

doggo = Dog('Pupppo')

felix = Cat('Felix')

pussycat = Cat('Pussy')


print(niko.speak())

print(felix.speak())

print(doggo.speak())

print(pussycat.speak())
# Out:
# Niko says Woof!
# Felix says Meow!
# Pupppo says Woof!
# Pussy says Meow!

# %%
umra =Cat('uwaim')

# %%
print(umra.speak())
# Out:
# uwaim says Meow!

# %%
for pet in [niko,felix,doggo,pussycat,umra]:
    print(pet.speak())
# Out:
# Niko says Woof!
# Felix says Meow!
# Pupppo says Woof!
# Pussy says Meow!
# uwaim says Meow!
