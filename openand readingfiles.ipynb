# %%
pwd
# Out:
# 'C:\\Users\\Umra Ismat\\programs\\python-learning'

# %%
f=  open('practice','w+')
f.write('this is a practice file')
f.close
# Out:
# <function TextIOWrapper.close()>

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Umra Ismat\\programs\\python-learning'

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '._07-Statements Assessment Test.ipynb',
#  '._09-Objects and Data Structures Assessment Test.ipynb',
#  '02-Errors and Exceptions Homework.ipynb',
#  '03-Milestone Project 2 - Complete Walkthrough Solution.ipynb',
#  '07-Statements Assessment Test.ipynb',
#  '09-Objects and Data Structures Assessment Test.ipynb',
#  'bitwise_operator program.ipynb',
#  'consecutive1s.ipynb',
#  'countoflongestconsecutive1s.ipynb',
#  'countor_handon_umra.ipynb',
#  'decorators_practice.ipynb',
#  'decorator_handonexprence.ipynb',
#  'decorator_umra_part1.ipynb',
#  'error_exception.ipynb',
#  'expression_part1 .ipynb',
#  'filesio.ipynb',
#  'flasklearn',
#  'genrator_hands_on_expre.ipynb',
#  'hackerrank-programs',
#  'mathspowceilfunction.ipynb',
#  'myfile.text',
#  'myfile.txt',
#  'my_fav_file.txt',
#  'newdummy.txt',
#  'nptel-dsa',
#  'ok',
#  'olo.py',
#  'openand readingfiles.ipynb',
#  'practice',
#  'testfile',
#  'testing helo.ipynb',
# ...

# %%
os.listdir('C:\\Users')
# Out:
# ['All Users', 'Default', 'Default User', 'desktop.ini', 'Public', 'Umra Ismat']

# %%
import shutil

# %%
shutil.move('practice',C:\\Users\\Umra Ismat\\programs\hackerrank-programs\untitled.ipynb')
# Out:
#   Cell In[46], line 1
#     shutil.move('practice',C:\\Users\\Umra Ismat\\programs\hackerrank-programs\untitled.ipynb')
#                             ^
# SyntaxError: invalid syntax

# %%
import datetime

# %%
mytime = datetime.time(13,20,10,8)

# %%
mytime.hour
# Out:
# 13

# %%
type(mytime)
# Out:
# datetime.time

# %%
print(mytime)
# Out:
# 13:20:10.000008

# %%
today = datetime.time.today()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 today = datetime.time.today()
#
# AttributeError: type object 'datetime.time' has no attribute 'today'
