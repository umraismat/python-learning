# %% [markdown]
#                          OUR FIRST  THOUGHT PYTHON---GCD---

# %%
def gcd():
 # its a function in ehich mand n is beoing passed
    fm = []
    # fm indicates a factor of m here
    for i in range(1,m+1):
        # its is the rane from 1 to m+1 because if we ch
        if m%i==0:
            #if m divide completly  then:
            fm.append(i)
            #then i  will add in fm list

    fn = []
        # fn indicates a factor of m here
    for j  in  range(1,n+1):
       # fn indicates a factor of m here
        if n%j ==0:
      #if n divide completly  then:
            fn.append(j)
            #then j  will add in fn list


    cf=[]
    for f in fm:
        if f in fn:
            cf.append(f)

    return(cf[-1])       

    

# its a function in ehich mand n is beoing passed

# %%
import datetime

# %%
mytime = datetime.time(2,10,6)

# %%
mytime.minute
# Out:
# 10

# %%
mytime.hour
# Out:
# 2

# %%
print(mytime)
# Out:
# 02:10:06

# %%
mytime.microsecond
# Out:
# 0

# %%
type(mytime)
# Out:
# datetime.time

# %%
today = datetime.date.today()

# %%
print(today)
# Out:
# 2026-03-14

# %%
today.year
# Out:
# 2026

# %%
today.month
# Out:
# 3

# %%
today.day
# Out:
# 14

# %%
today.ctime()
# Out:
# 'Sat Mar 14 00:00:00 2026'

# %%
from datetime import datetime

# %%
mydatetime = datetime(2021,10,3,14,20,1)

# %%
print(mydatetime)
# Out:
# 2021-10-03 14:20:01

# %%
mydatetime = mydatetime.replace(year=2020)

# %%
print(mydatetime)
# Out:
# 2020-10-03 14:20:01

# %% [markdown]
# date

# %%
from datetime import date

# %%
date1 = datetime(2016,12,1)
date2 = datetime(2015,12,1)

# %%
result = date1-date2

# %%
print(result)
# Out:
# 366 days, 0:00:00

# %%
result.days
# Out:
# 366

# %%
datetime1 = datetime(2021,11,3,22,0)

# %%
datetime2 = datetime(2020,11,3,10,0)

# %%
interval = datetime1 - datetime2

# %%
print(interval)
# Out:
# 365 days, 12:00:00
